# %%
import yfinance as yf
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import scipy

# %%
data = yf.Ticker("MSFT")

# %%
df = data.history(period='max')
df.head(1)
# Out:
#                 Open      High       Low     Close      Volume  Dividends  \
# Date
# 1986-03-13  0.055783  0.063987  0.055783  0.061252  1031788800        0.0
#
#             Stock Splits
# Date
# 1986-03-13           0.0

# %%
df.tail(2)
# Out:
#                   Open        High         Low       Close    Volume  \
# Date
# 2022-03-10  283.019989  286.600006  280.579987  285.589996  30604500
# 2022-03-11  287.959991  288.918915  283.250000  284.515015  11991767
#
#             Dividends  Stock Splits
# Date
# 2022-03-10        0.0           0.0
# 2022-03-11        0.0           0.0

# %%
df.shape
# Out:
# (9074, 7)

# %%
plt.figure(figsize=(20,5))
plt.plot(df.index, df.Close, label="Close")
plt.plot(df.index, df.High, label="High")
plt.plot(df.index, df.Low, label="low")
plt.legend()

# %%
df["SMA_20"] = df["Close"].rolling(window=20).mean()

# %%
df.index.year
# Out:
# Int64Index([1986, 1986, 1986, 1986, 1986, 1986, 1986, 1986, 1986, 1986,
#             ...
#             2022, 2022, 2022, 2022, 2022, 2022, 2022, 2022, 2022, 2022],
#            dtype='int64', name='Date', length=9074)

# %%
df["Close"].
# Out:
#                   Open        High         Low       Close      Volume  \
# Date
# 1986-03-13    0.055783    0.063987    0.055783    0.061252  1031788800
# 1986-03-14    0.061252    0.064533    0.061252    0.063439   308160000
# 1986-03-17    0.063439    0.065080    0.063439    0.064533   133171200
# 1986-03-18    0.064533    0.065080    0.062345    0.062892    67766400
# 1986-03-19    0.062892    0.063439    0.061252    0.061799    47894400
# ...                ...         ...         ...         ...         ...
# 2022-03-07  288.529999  289.690002  278.529999  278.910004    43157200
# 2022-03-08  277.799988  283.959991  270.000000  275.850006    48159500
# 2022-03-09  283.440002  289.600006  280.779999  288.500000    35204500
# 2022-03-10  283.019989  286.600006  280.579987  285.589996    30604500
# 2022-03-11  287.959991  288.918915  283.250000  284.515015    11991767
#
#             Dividends  Stock Splits      SMA_20
# Date
# 1986-03-13        0.0           0.0         NaN
# ...

# %%
plt.figure(figsize=(20,5))
plt.plot(df.index, df.Close, label="Close")
plt.plot(df.index, df.SMA_20, label="SMA")
plt.legend()

# %%
t = Ticker("MSDF")

t.backtest()
t.plot()
t.simulate()

# %%
for t in list_tickers:
    x = Ticker(t)
    x.backtest()
    x.plot()

# %%
class Instrumento():
    def __init__(self, ticker):
        self.ticker = ticker
        self.data = yf.Ticker(ticker)
        self.df = self.data.history(period='max')
        self.df["SMA_20"] = self.df["Close"].rolling(window=20).mean()
        
    def backtest(self, period):
        pass
    
    def plot(self):
        plt.figure(figsize=(20,5))
        plt.plot(self.df.index, self.df.Close, label="Close")
        plt.plot(self.df.index, self.df.SMA_20, label="SMA")
        plt.title(self.ticker)
        plt.legend()
    
    def simulate(self):
        pass

# %%
x = Instrumento("MSFT")

# %%
x.data
# Out:
# yfinance.Ticker object <MSFT>

# %%
x.plot()

# %%
for i in ["AAPL","MSFT","BTC"]:
    x = Instrumento(i)
    #x.backtest()
    x.plot()
